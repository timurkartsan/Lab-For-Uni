# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
# generation of synthetic dataset
N = 100
a = 1
b = 3

x = np.random.uniform(0, 5, N)
noise = np.random.normal(0, .5, N)
y = a * x + b + noise

plt.grid()
plt.scatter(x, y, marker = '.', color = 'r')

# %%
X = x.reshape(-1, 1)

# %%
x # 1d array
# Out:
# array([3.97871387, 4.14583092, 1.86033232, 4.44139507, 4.23969166,
#        1.17714288, 0.75696936, 1.54269579, 4.06986913, 4.31725031,
#        3.61022718, 1.01350967, 0.49424019, 4.74891415, 2.76992932,
#        4.39513252, 2.66526579, 4.02811908, 2.39920611, 1.62436191,
#        0.08608259, 1.49262579, 4.84798184, 2.23282432, 4.36233758,
#        1.05110621, 0.94269279, 4.71481875, 1.41725273, 3.97310918,
#        1.91032583, 3.63255209, 4.94669084, 2.04551484, 0.24947035,
#        2.64972726, 2.598332  , 3.7574299 , 3.18709611, 2.78314029,
#        1.17454615, 3.82528741, 1.47105854, 4.33533226, 3.62603214,
#        2.68705397, 3.6129056 , 4.30173186, 3.22585914, 2.76200389,
#        4.10697688, 0.54770116, 2.10030913, 1.2652757 , 3.66624946,
#        2.36480254, 3.91687224, 4.59486711, 2.99837149, 3.05817971,
#        3.56425918, 1.76531698, 0.68090486, 3.61339473, 1.82373464,
#        0.91237801, 2.96784753, 3.20425884, 0.07534669, 0.39542552,
#        0.14361842, 3.14963882, 1.58379795, 3.57670423, 4.61512684,
#        4.12233613, 4.73820613, 0.83451455, 3.5719197 , 2.94595198,
#        4.6593893 , 1.03460648, 1.67913019, 2.59238461, 2.63922775,
#        2.31186812, 2.25126949, 3.9876497 , 0.79375923, 2.4172955 ,
#        3.71913237, 4.1035654 , 3.33963413, 0.81200477, 1.21629207,
#        3.90515779, 2.51046888, 4.79710544, 0.14139775, 0.96912141])

# %%
X # array where each row is an array to
# Out:
# array([[3.97871387],
#        [4.14583092],
#        [1.86033232],
#        [4.44139507],
#        [4.23969166],
#        [1.17714288],
#        [0.75696936],
#        [1.54269579],
#        [4.06986913],
#        [4.31725031],
#        [3.61022718],
#        [1.01350967],
#        [0.49424019],
#        [4.74891415],
#        [2.76992932],
#        [4.39513252],
#        [2.66526579],
#        [4.02811908],
#        [2.39920611],
#        [1.62436191],
#        [0.08608259],
#        [1.49262579],
#        [4.84798184],
#        [2.23282432],
#        [4.36233758],
#        [1.05110621],
#        [0.94269279],
#        [4.71481875],
#        [1.41725273],
#        [3.97310918],
#        [1.91032583],
#        [3.63255209],
#        [4.94669084],
#        [2.04551484],
#        [0.24947035],
#        [2.64972726],
#        [2.598332  ],
#        [3.7574299 ],
#        [3.18709611],
#        [2.78314029],
#        [1.17454615],
#        [3.82528741],
#        [1.47105854],
#        [4.33533226],
#        [3.62603214],
#        [2.68705397],
#        [3.6129056 ],
#        [4.30173186],
#        [3.22585914],
#        [2.76200389],
#        [4.10697688],
#        [0.54770116],
#        [2.10030913],
#        [1.2652757 ],
#        [3.66624946],
#        [2.36480254],
#        [3.91687224],
#        [4.59486711],
#        [2.99837149],
#        [3.05817971],
#        [3.56425918],
#        [1.76531698],
#        [0.68090486],
#        [3.61339473],
#        [1.82373464],
#        [0.91237801],
#        [2.96784753],
#        [3.20425884],
#        [0.07534669],
#        [0.39542552],
#        [0.14361842],
#        [3.14963882],
#        [1.58379795],
#        [3.57670423],
#        [4.61512684],
#        [4.12233613],
#        [4.73820613],
#        [0.83451455],
#        [3.5719197 ],
#        [2.94595198],
#        [4.6593893 ],
#        [1.03460648],
#        [1.67913019],
#        [2.59238461],
#        [2.63922775],
#        [2.31186812],
#        [2.25126949],
#        [3.9876497 ],
#        [0.79375923],
#        [2.4172955 ],
#        [3.71913237],
#        [4.1035654 ],
#        [3.33963413],
#        [0.81200477],
#        [1.21629207],
#        [3.90515779],
#        [2.51046888],
#        [4.79710544],
#        [0.14139775],
#        [0.96912141]])

# %%
# a * x + b = y

model = LinearRegression()
model.fit(X, y)
model
# Out:
# LinearRegression()

# %%
a_found = model.coef_[0]
b_found = model.intercept_

# %%
a_found
# Out:
# np.float64(1.0521647073609022)

# %%
b_found
# Out:
# np.float64(2.8123900522172707)
